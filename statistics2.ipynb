# %%
import glob
import json

import pandas as pd

# %%
paths = glob.glob("/n/home10/jlakha/llm-routing/outputs/experiment-1797682/runs/*.json")

# %%
# {2500, 5000, 7500, 10000} x {0.25, 0.5, 0.75, 1.0}: /n/home10/jlakha/llm-routing/outputs/experiment-1791347/runs/*.json"
# {1000, 2000, ..., 10000} x {0.0, 0.1, ..., 1.0}: /n/home10/jlakha/llm-routing/outputs/experiment-1797682/runs/*.json"

# %%
statistics = {}

for path in paths:
    with open(path, "r") as f:
        run = json.load(f)
    
    target_cost = run['config']['target_cost']
    target_load = run['config']['target_load']
    quality = run['total']['quality']['mean']
    latency = run['total']['latency']['mean']
    predictor = run['config']['quality_predictor']
    share_70b = run['meta-llama/Llama-3.1-70B-Instruct']['num_tokens']['share']
    run_identifier = run['config']['run_identifier']
        
    if target_cost not in statistics:
        statistics[target_cost] = {}
    
    if predictor not in statistics[target_cost]:
        statistics[target_cost][predictor] = {}
    
    statistics[target_cost][predictor][target_load] = {
        'latency': latency,
        'mean_quality': quality,
        'predictor': predictor,
        'target_load': target_load,
        'tokens_70_share': share_70b,
        'run_identifier': run_identifier,
    }
    

statistics
# Out:
# {0.4: {'perfect': {1000: {'latency': 9.69833262205124,
#     'mean_quality': 3.84,
#     'predictor': 'perfect',
#     'target_load': 1000,
#     'tokens_70_share': 0.127,
#     'run_identifier': '1797682-56'},
#    8000: {'latency': 71.73910795688629,
#     'mean_quality': 4.25,
#     'predictor': 'perfect',
#     'target_load': 8000,
#     'tokens_70_share': 0.385,
#     'run_identifier': '1797682-52'},
#    9000: {'latency': 80.15930609464645,
#     'mean_quality': 4.25,
#     'predictor': 'perfect',
#     'target_load': 9000,
#     'tokens_70_share': 0.385,
#     'run_identifier': '1797682-64'},
#    5000: {'latency': 42.90731979370117,
#     'mean_quality': 4.1,
#     'predictor': 'perfect',
#     'target_load': 5000,
#     'tokens_70_share': 0.279,
#     'run_identifier': '1797682-60'},
#    10000: {'latency': 73.81916588068009,
#     'mean_quality': 4.25,
#     'predictor': 'perfect',
#     'target_load': 10000,
#     'tokens_70_share': 0.385,
#     'run_identifier': '1797682-54'},
#    3000: {'latency': 25.619080309867858,
#     'mean_quality': 3.95,
#     'predictor': 'perfect',
#     'target_load': 3000,
#     'tokens_70_share': 0.212,
#     'run_identifier': '1797682-58'},
#    0: {'latency': 1.7860258793830872,
#     'mean_quality': 3.61,
#     'predictor': 'perfect',
#     'target_load': 0,
#     'tokens_70_share': 0.039,
#     'run_identifier': '1797682-44'},
#    2000: {'latency': 13.366436493396758,
#     'mean_quality': 3.78,
#     'predictor': 'perfect',
#     'target_load': 2000,
#     'tokens_70_share': 0.153,
#     'run_identifier': '1797682-46'},
#    7000: {'latency': 63.550110528469084,
#     'mean_quality': 4.22,
#     'predictor': 'perfect',
#     'target_load': 7000,
#     'tokens_70_share': 0.351,
#     'run_identifier': '1797682-62'},
#    4000: {'latency': 30.885635612010955,
#     'mean_quality': 3.98,
#     'predictor': 'perfect',
#     'target_load': 4000,
#     'tokens_70_share': 0.229,
#     'run_identifier': '1797682-48'},
#    6000: {'latency': 52.17997183084488,
#     'mean_quality': 4.15,
#     'predictor': 'perfect',
#     'target_load': 6000,
#     'tokens_70_share': 0.318,
#     'run_identifier': '1797682-50'}},
#   'random': {4000: {'latency': 23.091508107185362,
#     'mean_quality': 3.64,
#     'predictor': 'random',
#     'target_load': 4000,
#     'tokens_70_share': 0.257,
#     'run_identifier': '1797682-49'},
#    6000: {'latency': 41.45421407461166,
#     'mean_quality': 3.67,
#     'predictor': 'random',
#     'target_load': 6000,
#     'tokens_70_share': 0.346,
#     'run_identifier': '1797682-51'},
#    7000: {'latency': 45.8511639046669,
#     'mean_quality': 3.72,
#     'predictor': 'random',
#     'target_load': 7000,
#     'tokens_70_share': 0.299,
#     'run_identifier': '1797682-63'},
#    10000: {'latency': 61.77682913303375,
#     'mean_quality': 3.77,
#     'predictor': 'random',
#     'target_load': 10000,
#     'tokens_70_share': 0.397,
#     'run_identifier': '1797682-55'},
#    3000: {'latency': 18.74476634979248,
#     'mean_quality': 3.65,
#     'predictor': 'random',
#     'target_load': 3000,
#     'tokens_70_share': 0.201,
#     'run_identifier': '1797682-59'},
#    5000: {'latency': 46.63164504766464,
#     'mean_quality': 3.63,
#     'predictor': 'random',
#     'target_load': 5000,
#     'tokens_70_share': 0.321,
#     'run_identifier': '1797682-61'},
#    2000: {'latency': 16.824638288021088,
#     'mean_quality': 3.63,
#     'predictor': 'random',
#     'target_load': 2000,
#     'tokens_70_share': 0.186,
#     'run_identifier': '1797682-47'},
#    9000: {'latency': 54.19827470064163,
#     'mean_quality': 3.81,
#     'predictor': 'random',
#     'target_load': 9000,
#     'tokens_70_share': 0.353,
#     'run_identifier': '1797682-65'},
#    1000: {'latency': 9.442150976657867,
#     'mean_quality': 3.5,
#     'predictor': 'random',
#     'target_load': 1000,
#     'tokens_70_share': 0.146,
#     'run_identifier': '1797682-57'},
#    8000: {'latency': 50.73888239860535,
#     'mean_quality': 3.61,
#     'predictor': 'random',
#     'target_load': 8000,
#     'tokens_70_share': 0.33,
#     'run_identifier': '1797682-53'},
#    0: {'latency': 2.3288740491867066,
#     'mean_quality': 3.44,
#     'predictor': 'random',
#     'target_load': 0,
#     'tokens_70_share': 0.044,
#     'run_identifier': '1797682-45'}}},
#  0.0: {'perfect': {5000: {'latency': 1.8164003014564514,
#     'mean_quality': 3.41,
#     'predictor': 'perfect',
#     'target_load': 5000,
#     'tokens_70_share': 0.019,
#     'run_identifier': '1797682-16'},
#    4000: {'latency': 1.7979153108596801,
#     'mean_quality': 3.41,
#     'predictor': 'perfect',
#     'target_load': 4000,
#     'tokens_70_share': 0.019,
#     'run_identifier': '1797682-4'},
#    2000: {'latency': 2.3668104720115664,
#     'mean_quality': 3.41,
#     'predictor': 'perfect',
#     'target_load': 2000,
#     'tokens_70_share': 0.019,
#     'run_identifier': '1797682-2'},
#    10000: {'latency': 1.6170401525497438,
#     'mean_quality': 3.41,
#     'predictor': 'perfect',
#     'target_load': 10000,
#     'tokens_70_share': 0.019,
#     'run_identifier': '1797682-10'},
#    0: {'latency': 1.7793299865722656,
#     'mean_quality': 3.4,
#     'predictor': 'perfect',
#     'target_load': 0,
#     'tokens_70_share': 0.003,
#     'run_identifier': '1797682-0'},
#    1000: {'latency': 1.535259611606598,
#     'mean_quality': 3.41,
#     'predictor': 'perfect',
#     'target_load': 1000,
#     'tokens_70_share': 0.019,
#     'run_identifier': '1797682-12'},
#    9000: {'latency': 1.3374615049362182,
#     'mean_quality': 3.41,
#     'predictor': 'perfect',
#     'target_load': 9000,
#     'tokens_70_share': 0.019,
#     'run_identifier': '1797682-20'},
#    7000: {'latency': 1.4361656951904296,
#     'mean_quality': 3.41,
#     'predictor': 'perfect',
#     'target_load': 7000,
#     'tokens_70_share': 0.019,
#     'run_identifier': '1797682-18'},
#    6000: {'latency': 1.7188365030288697,
#     'mean_quality': 3.41,
#     'predictor': 'perfect',
#     'target_load': 6000,
#     'tokens_70_share': 0.019,
#     'run_identifier': '1797682-6'},
#    8000: {'latency': 1.3131562376022339,
#     'mean_quality': 3.41,
#     'predictor': 'perfect',
#     'target_load': 8000,
#     'tokens_70_share': 0.019,
#     'run_identifier': '1797682-8'},
#    3000: {'latency': 2.3750871419906616,
#     'mean_quality': 3.41,
#     'predictor': 'perfect',
#     'target_load': 3000,
#     'tokens_70_share': 0.019,
#     'run_identifier': '1797682-14'}},
#   'random': {8000: {'latency': 1.7711253714561463,
#     'mean_quality': 3.41,
#     'predictor': 'random',
#     'target_load': 8000,
#     'tokens_70_share': 0.022,
#     'run_identifier': '1797682-9'},
#    6000: {'latency': 3.4162549901008608,
#     'mean_quality': 3.38,
#     'predictor': 'random',
#     'target_load': 6000,
#     'tokens_70_share': 0.062,
#     'run_identifier': '1797682-7'},
#    9000: {'latency': 2.609473123550415,
#     'mean_quality': 3.42,
#     'predictor': 'random',
#     'target_load': 9000,
#     'tokens_70_share': 0.042,
#     'run_identifier': '1797682-21'},
#    1000: {'latency': 2.686394293308258,
#     'mean_quality': 3.44,
#     'predictor': 'random',
#     'target_load': 1000,
#     'tokens_70_share': 0.038,
#     'run_identifier': '1797682-13'},
#    0: {'latency': 1.2509908080101013,
#     'mean_quality': 3.38,
#     'predictor': 'random',
#     'target_load': 0,
#     'tokens_70_share': 0.017,
#     'run_identifier': '1797682-1'},
#    7000: {'latency': 1.5846081209182739,
#     'mean_quality': 3.42,
#     'predictor': 'random',
#     'target_load': 7000,
#     'tokens_70_share': 0.022,
#     'run_identifier': '1797682-19'},
#    10000: {'latency': 2.074469339847565,
#     'mean_quality': 3.41,
#     'predictor': 'random',
#     'target_load': 10000,
#     'tokens_70_share': 0.019,
#     'run_identifier': '1797682-11'},
#    2000: {'latency': 2.232937412261963,
#     'mean_quality': 3.41,
#     'predictor': 'random',
#     'target_load': 2000,
#     'tokens_70_share': 0.019,
#     'run_identifier': '1797682-3'},
#    5000: {'latency': 1.8499987936019897,
#     'mean_quality': 3.4,
#     'predictor': 'random',
#     'target_load': 5000,
#     'tokens_70_share': 0.021,
#     'run_identifier': '1797682-17'},
#    4000: {'latency': 2.567395133972168,
#     'mean_quality': 3.41,
#     'predictor': 'random',
#     'target_load': 4000,
#     'tokens_70_share': 0.024,
#     'run_identifier': '1797682-5'},
#    3000: {'latency': 4.076417708396912,
#     'mean_quality': 3.45,
#     'predictor': 'random',
#     'target_load': 3000,
#     'tokens_70_share': 0.077,
#     'run_identifier': '1797682-15'}}},
#  0.6: {'random': {3000: {'latency': 35.98906351804733,
#     'mean_quality': 3.73,
#     'predictor': 'random',
#     'target_load': 3000,
#     'tokens_70_share': 0.243,
#     'run_identifier': '1797682-81'},
#    6000: {'latency': 61.277513251304626,
#     'mean_quality': 3.8,
#     'predictor': 'random',
#     'target_load': 6000,
#     'tokens_70_share': 0.355,
#     'run_identifier': '1797682-73'},
#    10000: {'latency': 153.4927317214012,
#     'mean_quality': 3.94,
#     'predictor': 'random',
#     'target_load': 10000,
#     'tokens_70_share': 0.552,
#     'run_identifier': '1797682-77'},
#    2000: {'latency': 16.367703619003297,
#     'mean_quality': 3.57,
#     'predictor': 'random',
#     'target_load': 2000,
#     'tokens_70_share': 0.212,
#     'run_identifier': '1797682-69'},
#    4000: {'latency': 34.694922406673435,
#     'mean_quality': 3.67,
#     'predictor': 'random',
#     'target_load': 4000,
#     'tokens_70_share': 0.242,
#     'run_identifier': '1797682-71'},
#    8000: {'latency': 101.98827597618103,
#     'mean_quality': 3.91,
#     'predictor': 'random',
#     'target_load': 8000,
#     'tokens_70_share': 0.445,
#     'run_identifier': '1797682-75'},
#    0: {'latency': 2.5556614875793455,
#     'mean_quality': 3.46,
#     'predictor': 'random',
#     'target_load': 0,
#     'tokens_70_share': 0.067,
#     'run_identifier': '1797682-67'},
#    1000: {'latency': 7.384615557193756,
#     'mean_quality': 3.45,
#     'predictor': 'random',
#     'target_load': 1000,
#     'tokens_70_share': 0.136,
#     'run_identifier': '1797682-79'},
#    7000: {'latency': 54.16811607122421,
#     'mean_quality': 3.65,
#     'predictor': 'random',
#     'target_load': 7000,
#     'tokens_70_share': 0.354,
#     'run_identifier': '1797682-85'},
#    5000: {'latency': 47.59169980525971,
#     'mean_quality': 3.7,
#     'predictor': 'random',
#     'target_load': 5000,
#     'tokens_70_share': 0.302,
#     'run_identifier': '1797682-83'}},
#   'perfect': {6000: {'latency': 58.314596548080445,
#     'mean_quality': 4.04,
#     'predictor': 'perfect',
#     'target_load': 6000,
#     'tokens_70_share': 0.338,
#     'run_identifier': '1797682-72'},
#    4000: {'latency': 48.088086652755734,
#     'mean_quality': 4.03,
#     'predictor': 'perfect',
#     'target_load': 4000,
#     'tokens_70_share': 0.297,
#     'run_identifier': '1797682-70'},
#    2000: {'latency': 14.101346998214721,
#     'mean_quality': 3.68,
#     'predictor': 'perfect',
#     'target_load': 2000,
#     'tokens_70_share': 0.171,
#     'run_identifier': '1797682-68'},
#    3000: {'latency': 32.90159554004669,
#     'mean_quality': 3.88,
#     'predictor': 'perfect',
#     'target_load': 3000,
#     'tokens_70_share': 0.245,
#     'run_identifier': '1797682-80'},
#    10000: {'latency': 124.73991488218307,
#     'mean_quality': 4.35,
#     'predictor': 'perfect',
#     'target_load': 10000,
#     'tokens_70_share': 0.518,
#     'run_identifier': '1797682-76'},
#    1000: {'latency': 10.802046282291412,
#     'mean_quality': 3.76,
#     'predictor': 'perfect',
#     'target_load': 1000,
#     'tokens_70_share': 0.135,
#     'run_identifier': '1797682-78'},
#    8000: {'latency': 81.31563077688217,
#     'mean_quality': 4.21,
#     'predictor': 'perfect',
#     'target_load': 8000,
#     'tokens_70_share': 0.394,
#     'run_identifier': '1797682-74'},
#    5000: {'latency': 44.019026207923886,
#     'mean_quality': 3.93,
#     'predictor': 'perfect',
#     'target_load': 5000,
#     'tokens_70_share': 0.29,
#     'run_identifier': '1797682-82'},
#    7000: {'latency': 70.312055850029,
#     'mean_quality': 4.11,
#     'predictor': 'perfect',
#     'target_load': 7000,
#     'tokens_70_share': 0.356,
#     'run_identifier': '1797682-84'},
#    0: {'latency': 2.49069949388504,
#     'mean_quality': 3.62,
#     'predictor': 'perfect',
#     'target_load': 0,
#     'tokens_70_share': 0.033,
#     'run_identifier': '1797682-66'}}},
#  0.2: {'perfect': {0: {'latency': 1.616723551750183,
#     'mean_quality': 3.53,
#     'predictor': 'perfect',
#     'target_load': 0,
#     'tokens_70_share': 0.045,
#     'run_identifier': '1797682-22'},
#    9000: {'latency': 23.55279334068298,
#     'mean_quality': 4.06,
#     'predictor': 'perfect',
#     'target_load': 9000,
#     'tokens_70_share': 0.21,
#     'run_identifier': '1797682-42'},
#    10000: {'latency': 19.67941153526306,
#     'mean_quality': 4.06,
#     'predictor': 'perfect',
#     'target_load': 10000,
#     'tokens_70_share': 0.21,
#     'run_identifier': '1797682-32'},
#    1000: {'latency': 6.642861871719361,
#     'mean_quality': 3.74,
#     'predictor': 'perfect',
#     'target_load': 1000,
#     'tokens_70_share': 0.11,
#     'run_identifier': '1797682-34'},
#    5000: {'latency': 23.445742750167845,
#     'mean_quality': 4.06,
#     'predictor': 'perfect',
#     'target_load': 5000,
#     'tokens_70_share': 0.21,
#     'run_identifier': '1797682-38'},
#    3000: {'latency': 13.953119904994965,
#     'mean_quality': 3.93,
#     'predictor': 'perfect',
#     'target_load': 3000,
#     'tokens_70_share': 0.183,
#     'run_identifier': '1797682-36'},
#    7000: {'latency': 22.83115702390671,
#     'mean_quality': 4.06,
#     'predictor': 'perfect',
#     'target_load': 7000,
#     'tokens_70_share': 0.21,
#     'run_identifier': '1797682-40'},
#    4000: {'latency': 25.00571893930435,
#     'mean_quality': 4.06,
#     'predictor': 'perfect',
#     'target_load': 4000,
#     'tokens_70_share': 0.21,
#     'run_identifier': '1797682-26'},
#    6000: {'latency': 23.237458095550537,
#     'mean_quality': 4.06,
#     'predictor': 'perfect',
#     'target_load': 6000,
#     'tokens_70_share': 0.21,
#     'run_identifier': '1797682-28'},
#    2000: {'latency': 11.437736847400664,
#     'mean_quality': 3.89,
#     'predictor': 'perfect',
#     'target_load': 2000,
#     'tokens_70_share': 0.153,
#     'run_identifier': '1797682-24'},
#    8000: {'latency': 22.13157636165619,
#     'mean_quality': 4.06,
#     'predictor': 'perfect',
#     'target_load': 8000,
#     'tokens_70_share': 0.21,
#     'run_identifier': '1797682-30'}},
#   'random': {3000: {'latency': 15.189072165489197,
#     'mean_quality': 3.51,
#     'predictor': 'random',
#     'target_load': 3000,
#     'tokens_70_share': 0.152,
#     'run_identifier': '1797682-37'},
#    1000: {'latency': 4.745337455272675,
#     'mean_quality': 3.48,
#     'predictor': 'random',
#     'target_load': 1000,
#     'tokens_70_share': 0.128,
#     'run_identifier': '1797682-35'},
#    5000: {'latency': 8.350005111694337,
#     'mean_quality': 3.52,
#     'predictor': 'random',
#     'target_load': 5000,
#     'tokens_70_share': 0.124,
#     'run_identifier': '1797682-39'},
#    7000: {'latency': 19.042687330245972,
#     'mean_quality': 3.64,
#     'predictor': 'random',
#     'target_load': 7000,
#     'tokens_70_share': 0.233,
#     'run_identifier': '1797682-41'},
#    0: {'latency': 1.7840722465515138,
#     'mean_quality': 3.42,
#     'predictor': 'random',
#     'target_load': 0,
#     'tokens_70_share': 0.041,
#     'run_identifier': '1797682-23'},
#    6000: {'latency': 14.696916651725768,
#     'mean_quality': 3.6,
#     'predictor': 'random',
#     'target_load': 6000,
#     'tokens_70_share': 0.206,
#     'run_identifier': '1797682-29'},
#    9000: {'latency': 32.1916965174675,
#     'mean_quality': 3.73,
#     'predictor': 'random',
#     'target_load': 9000,
#     'tokens_70_share': 0.261,
#     'run_identifier': '1797682-43'},
#    4000: {'latency': 16.33330782175064,
#     'mean_quality': 3.63,
#     'predictor': 'random',
#     'target_load': 4000,
#     'tokens_70_share': 0.203,
#     'run_identifier': '1797682-27'},
#    10000: {'latency': 16.797867593765258,
#     'mean_quality': 3.58,
#     'predictor': 'random',
#     'target_load': 10000,
#     'tokens_70_share': 0.186,
#     'run_identifier': '1797682-33'},
#    8000: {'latency': 11.772866606712341,
#     'mean_quality': 3.52,
#     'predictor': 'random',
#     'target_load': 8000,
#     'tokens_70_share': 0.169,
#     'run_identifier': '1797682-31'},
#    2000: {'latency': 11.13838748216629,
#     'mean_quality': 3.62,
#     'predictor': 'random',
#     'target_load': 2000,
#     'tokens_70_share': 0.184,
#     'run_identifier': '1797682-25'}}}}

# %%
pd.set_option('display.width', 1000)

# %%
statistics = dict(sorted(statistics.items()))

for target_cost, v in statistics.items():
    v = dict(sorted(v.items()))
    for router, data in v.items():
        data = dict(sorted(data.items()))
        print(target_cost, router)
        print(pd.DataFrame(data))
        print('\n\n')
# Out:
# 0.0 perfect
#                      0           1000       2000        3000       4000        5000       6000        7000       8000        9000        10000
# latency            1.77933     1.53526    2.36681    2.375087   1.797915      1.8164   1.718837    1.436166   1.313156    1.337462     1.61704
# mean_quality           3.4        3.41       3.41        3.41       3.41        3.41       3.41        3.41       3.41        3.41        3.41
# predictor          perfect     perfect    perfect     perfect    perfect     perfect    perfect     perfect    perfect     perfect     perfect
# target_load              0        1000       2000        3000       4000        5000       6000        7000       8000        9000       10000
# tokens_70_share      0.003       0.019      0.019       0.019      0.019       0.019      0.019       0.019      0.019       0.019       0.019
# run_identifier   1797682-0  1797682-12  1797682-2  1797682-14  1797682-4  1797682-16  1797682-6  1797682-18  1797682-8  1797682-20  1797682-10
#
#
#
# 0.0 random
#                      0           1000       2000        3000       4000        5000       6000        7000       8000        9000        10000
# latency           1.250991    2.686394   2.232937    4.076418   2.567395    1.849999   3.416255    1.584608   1.771125    2.609473    2.074469
# mean_quality          3.38        3.44       3.41        3.45       3.41         3.4       3.38        3.42       3.41        3.42        3.41
# predictor           random      random     random      random     random      random     random      random     random      random      random
# target_load              0        1000       2000        3000       4000        5000       6000        7000       8000        9000       10000
# tokens_70_share      0.017       0.038      0.019       0.077      0.024       0.021      0.062       0.022      0.022       0.042       0.019
# run_identifier   1797682-1  1797682-13  1797682-3  1797682-15  1797682-5  1797682-17  1797682-7  1797682-19  1797682-9  1797682-21  1797682-11
#
#
#
# 0.2 perfect
#                       0           1000        2000        3000        4000        5000        6000        7000        8000        9000        10000
# latency            1.616724    6.642862   11.437737    13.95312   25.005719   23.445743   23.237458   22.831157   22.131576   23.552793   19.679412
# mean_quality           3.53        3.74        3.89        3.93        4.06        4.06        4.06        4.06        4.06        4.06        4.06
# predictor           perfect     perfect     perfect     perfect     perfect     perfect     perfect     perfect     perfect     perfect     perfect
# target_load               0        1000        2000        3000        4000        5000        6000        7000        8000        9000       10000
# tokens_70_share       0.045        0.11       0.153       0.183        0.21        0.21        0.21        0.21        0.21        0.21        0.21
# run_identifier   1797682-22  1797682-34  1797682-24  1797682-36  1797682-26  1797682-38  1797682-28  1797682-40  1797682-30  1797682-42  1797682-32
#
#
#
# 0.2 random
#                       0           1000        2000        3000        4000        5000        6000        7000        8000        9000        10000
# latency            1.784072    4.745337   11.138387   15.189072   16.333308    8.350005   14.696917   19.042687   11.772867   32.191697   16.797868
# mean_quality           3.42        3.48        3.62        3.51        3.63        3.52         3.6        3.64        3.52        3.73        3.58
# predictor            random      random      random      random      random      random      random      random      random      random      random
# target_load               0        1000        2000        3000        4000        5000        6000        7000        8000        9000       10000
# tokens_70_share       0.041       0.128       0.184       0.152       0.203       0.124       0.206       0.233       0.169       0.261       0.186
# run_identifier   1797682-23  1797682-35  1797682-25  1797682-37  1797682-27  1797682-39  1797682-29  1797682-41  1797682-31  1797682-43  1797682-33
#
#
#
# 0.4 perfect
#                       0           1000        2000        3000        4000        5000        6000        7000        8000        9000        10000
# latency            1.786026    9.698333   13.366436    25.61908   30.885636    42.90732   52.179972   63.550111   71.739108   80.159306   73.819166
# mean_quality           3.61        3.84        3.78        3.95        3.98         4.1        4.15        4.22        4.25        4.25        4.25
# predictor           perfect     perfect     perfect     perfect     perfect     perfect     perfect     perfect     perfect     perfect     perfect
# target_load               0        1000        2000        3000        4000        5000        6000        7000        8000        9000       10000
# tokens_70_share       0.039       0.127       0.153       0.212       0.229       0.279       0.318       0.351       0.385       0.385       0.385
# run_identifier   1797682-44  1797682-56  1797682-46  1797682-58  1797682-48  1797682-60  1797682-50  1797682-62  1797682-52  1797682-64  1797682-54
#
#
#
# 0.4 random
#                       0           1000        2000        3000        4000        5000        6000        7000        8000        9000        10000
# latency            2.328874    9.442151   16.824638   18.744766   23.091508   46.631645   41.454214   45.851164   50.738882   54.198275   61.776829
# mean_quality           3.44         3.5        3.63        3.65        3.64        3.63        3.67        3.72        3.61        3.81        3.77
# predictor            random      random      random      random      random      random      random      random      random      random      random
# target_load               0        1000        2000        3000        4000        5000        6000        7000        8000        9000       10000
# tokens_70_share       0.044       0.146       0.186       0.201       0.257       0.321       0.346       0.299        0.33       0.353       0.397
# run_identifier   1797682-45  1797682-57  1797682-47  1797682-59  1797682-49  1797682-61  1797682-51  1797682-63  1797682-53  1797682-65  1797682-55
#
#
#
# 0.6 perfect
#                       0           1000        2000        3000        4000        5000        6000        7000        8000        10000
# latency            2.490699   10.802046   14.101347   32.901596   48.088087   44.019026   58.314597   70.312056   81.315631  124.739915
# mean_quality           3.62        3.76        3.68        3.88        4.03        3.93        4.04        4.11        4.21        4.35
# predictor           perfect     perfect     perfect     perfect     perfect     perfect     perfect     perfect     perfect     perfect
# target_load               0        1000        2000        3000        4000        5000        6000        7000        8000       10000
# tokens_70_share       0.033       0.135       0.171       0.245       0.297        0.29       0.338       0.356       0.394       0.518
# run_identifier   1797682-66  1797682-78  1797682-68  1797682-80  1797682-70  1797682-82  1797682-72  1797682-84  1797682-74  1797682-76
#
#
#
# 0.6 random
#                       0           1000        2000        3000        4000        5000        6000        7000        8000        10000
# latency            2.555661    7.384616   16.367704   35.989064   34.694922     47.5917   61.277513   54.168116  101.988276  153.492732
# mean_quality           3.46        3.45        3.57        3.73        3.67         3.7         3.8        3.65        3.91        3.94
# predictor            random      random      random      random      random      random      random      random      random      random
# target_load               0        1000        2000        3000        4000        5000        6000        7000        8000       10000
# tokens_70_share       0.067       0.136       0.212       0.243       0.242       0.302       0.355       0.354       0.445       0.552
# run_identifier   1797682-67  1797682-79  1797682-69  1797682-81  1797682-71  1797682-83  1797682-73  1797682-85  1797682-75  1797682-77
